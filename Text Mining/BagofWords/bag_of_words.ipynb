# %% [markdown]
# ## Bag Of Words
# ##### spam --->Some virus kind of thing which affects the system
# ##### Bags of words is going to
# ##### Drawbacks---> It is going to create sparcity

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/8-text_mining/text_mining/spam.csv')

# %%
df
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.head()
## Category is Target Column
## Messege is Data Column
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
#Balanced or unbalanced data
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['spam']=df['Category'].apply(lambda x: 1 if x=='spam'else 0)

# %%
df.shape
##5572 is no. of rows
##3 is no. of column
# Out:
# (5572, 3)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train ,y_test = train_test_split(df.Message,df.spam,test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %% [markdown]
# ## Create bag of words representation using CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
v=CountVectorizer()
X_train_cv=v.fit_transform(X_train.values)
#X_test_cv=v.fit_transform(X_test.values)#In same way we can do the same for test.
X_train_cv
#X_test_cv
# Out:
# <4457x7725 sparse matrix of type '<class 'numpy.int64'>'
# 	with 58613 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# ## Train the naive bayes model

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(X_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
X_test_cv = v.transform(X_test)

# %% [markdown]
# ## Evaluate Performance

# %%
from sklearn.metrics import classification_report
y_pred = model.predict(X_test_cv)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       947
#            1       0.97      0.92      0.94       168
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.96      0.97      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
emails = ['Hey mohan, can we get together to watch footbal game tomorrow?','Upto 20% discount on parking, exclusive offer just you.Dont miss this reward!']
emails_count=v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 1], dtype=int64)
